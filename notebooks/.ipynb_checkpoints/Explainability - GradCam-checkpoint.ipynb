# %%
# %load_ext autoreload
import sys
import torch
sys.path.append('../')
from experiment import OCTClassification
from nntools.utils import load_yaml
sys.path.append('../pytorch-grad-cam')
from gradcam import GradCam
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
trained_savedict = '/home/clement/Documents/Clement/runs/mlruns/1/e3c337f9fe6647cf9d61e81109fd6644/artifacts/iteration_380000_mIoU_0916.pth'
from opticNet import OpticNet
network = OpticNet(n_classes=4, n_channels=3)

network.load(trained_savedict)
network = network.cuda()
network.eval()
# Out:
# Loading model from  /home/clement/Documents/Clement/runs/mlruns/1/e3c337f9fe6647cf9d61e81109fd6644/artifacts/iteration_380000_mIoU_0916.pth
# OpticNet(
#   (first_layer): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): ResConv(
#       (branch_1): Sequential(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU()
#         (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU()
#         (5): ReflectionPad2d((1, 0, 1, 0))
#         (6): Conv2d(64, 64, kernel_size=(2, 2), stride=(1, 1))
#         (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (8): ReLU()
#         (9): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (branch_2): Sequential(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU()
#         (2): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#   )
#   (mid1): MidBlock(
#     (encoder_decoder): EncoderDecoder()
#     (rdbi): RDBI(
#       (layers): Sequential(
#         (0): ResIdentity(
#           (layer_1): Sequential(
#             (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (branch_1): Sequential(
#             (0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(32, 32, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2))
#           )
#           (branch_2): Sequential(
#             (0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): SeparableConv2d(
#               (depthwise): Conv2d(32, 32, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=32, bias=False)
#               (pointwise): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (out): Sequential(
#             (0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(32, 256, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (1): ResIdentity(
#           (layer_1): Sequential(
#             (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (branch_1): Sequential(
#             (0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(32, 32, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2))
#           )
#           (branch_2): Sequential(
#             (0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): SeparableConv2d(
#               (depthwise): Conv2d(32, 32, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=32, bias=False)
#               (pointwise): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (out): Sequential(
#             (0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(32, 256, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (2): ResIdentity(
#           (layer_1): Sequential(
#             (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (branch_1): Sequential(
#             (0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(32, 32, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2))
#           )
#           (branch_2): Sequential(
#             (0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): SeparableConv2d(
#               (depthwise): Conv2d(32, 32, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=32, bias=False)
#               (pointwise): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (out): Sequential(
#             (0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(32, 256, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (3): ResIdentity(
#           (layer_1): Sequential(
#             (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (branch_1): Sequential(
#             (0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(32, 32, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2))
#           )
#           (branch_2): Sequential(
#             (0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): SeparableConv2d(
#               (depthwise): Conv2d(32, 32, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=32, bias=False)
#               (pointwise): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (out): Sequential(
#             (0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(32, 256, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#     )
#     (res_conv): ResConv(
#       (branch_1): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU()
#         (2): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU()
#         (5): ReflectionPad2d((1, 0, 1, 0))
#         (6): Conv2d(128, 128, kernel_size=(2, 2), stride=(2, 2))
#         (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (8): ReLU()
#         (9): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (branch_2): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU()
#         (2): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2))
#       )
#     )
#   )
#   (mid2): MidBlock(
#     (encoder_decoder): EncoderDecoder()
#     (rdbi): RDBI(
#       (layers): Sequential(
#         (0): ResIdentity(
#           (layer_1): Sequential(
#             (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (branch_1): Sequential(
#             (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(64, 64, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2))
#           )
#           (branch_2): Sequential(
#             (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): SeparableConv2d(
#               (depthwise): Conv2d(64, 64, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=64, bias=False)
#               (pointwise): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (out): Sequential(
#             (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(64, 512, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (1): ResIdentity(
#           (layer_1): Sequential(
#             (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (branch_1): Sequential(
#             (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(64, 64, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2))
#           )
#           (branch_2): Sequential(
#             (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): SeparableConv2d(
#               (depthwise): Conv2d(64, 64, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=64, bias=False)
#               (pointwise): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (out): Sequential(
#             (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(64, 512, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (2): ResIdentity(
#           (layer_1): Sequential(
#             (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (branch_1): Sequential(
#             (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(64, 64, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2))
#           )
#           (branch_2): Sequential(
#             (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): SeparableConv2d(
#               (depthwise): Conv2d(64, 64, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=64, bias=False)
#               (pointwise): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (out): Sequential(
#             (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(64, 512, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (3): ResIdentity(
#           (layer_1): Sequential(
#             (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (branch_1): Sequential(
#             (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(64, 64, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2))
#           )
#           (branch_2): Sequential(
#             (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): SeparableConv2d(
#               (depthwise): Conv2d(64, 64, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=64, bias=False)
#               (pointwise): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (out): Sequential(
#             (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(64, 512, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#     )
#     (res_conv): ResConv(
#       (branch_1): Sequential(
#         (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU()
#         (2): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU()
#         (5): ReflectionPad2d((1, 0, 1, 0))
#         (6): Conv2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#         (7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (8): ReLU()
#         (9): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (branch_2): Sequential(
#         (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU()
#         (2): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2))
#       )
#     )
#   )
#   (mid3): MidBlock(
#     (encoder_decoder): EncoderDecoder()
#     (rdbi): RDBI(
#       (layers): Sequential(
#         (0): ResIdentity(
#           (layer_1): Sequential(
#             (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (branch_1): Sequential(
#             (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(128, 128, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2))
#           )
#           (branch_2): Sequential(
#             (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): SeparableConv2d(
#               (depthwise): Conv2d(128, 128, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=128, bias=False)
#               (pointwise): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (out): Sequential(
#             (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(128, 1024, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (1): ResIdentity(
#           (layer_1): Sequential(
#             (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (branch_1): Sequential(
#             (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(128, 128, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2))
#           )
#           (branch_2): Sequential(
#             (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): SeparableConv2d(
#               (depthwise): Conv2d(128, 128, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=128, bias=False)
#               (pointwise): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (out): Sequential(
#             (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(128, 1024, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (2): ResIdentity(
#           (layer_1): Sequential(
#             (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (branch_1): Sequential(
#             (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(128, 128, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2))
#           )
#           (branch_2): Sequential(
#             (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): SeparableConv2d(
#               (depthwise): Conv2d(128, 128, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=128, bias=False)
#               (pointwise): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (out): Sequential(
#             (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(128, 1024, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#     )
#     (res_conv): ResConv(
#       (branch_1): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU()
#         (2): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#         (3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU()
#         (5): ReflectionPad2d((1, 0, 1, 0))
#         (6): Conv2d(512, 512, kernel_size=(2, 2), stride=(2, 2))
#         (7): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (8): ReLU()
#         (9): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (branch_2): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU()
#         (2): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2))
#       )
#     )
#   )
#   (mid4): MidBlock(
#     (encoder_decoder): EncoderDecoder()
#     (rdbi): RDBI(
#       (layers): Sequential(
#         (0): ResIdentity(
#           (layer_1): Sequential(
#             (0): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (branch_1): Sequential(
#             (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(256, 256, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2))
#           )
#           (branch_2): Sequential(
#             (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): SeparableConv2d(
#               (depthwise): Conv2d(256, 256, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=256, bias=False)
#               (pointwise): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (out): Sequential(
#             (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(256, 2048, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (1): ResIdentity(
#           (layer_1): Sequential(
#             (0): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (branch_1): Sequential(
#             (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(256, 256, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2))
#           )
#           (branch_2): Sequential(
#             (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): SeparableConv2d(
#               (depthwise): Conv2d(256, 256, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=256, bias=False)
#               (pointwise): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (out): Sequential(
#             (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(256, 2048, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (2): ResIdentity(
#           (layer_1): Sequential(
#             (0): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (branch_1): Sequential(
#             (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(256, 256, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2))
#           )
#           (branch_2): Sequential(
#             (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): SeparableConv2d(
#               (depthwise): Conv2d(256, 256, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=256, bias=False)
#               (pointwise): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (out): Sequential(
#             (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(256, 2048, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#     )
#     (res_conv): Identity()
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=256, bias=True)
#     (1): Linear(in_features=256, out_features=4, bias=True)
#   )
# )

# %%
config_path = '../config.yaml'
config = load_yaml(config_path)
experiment = OCTClassification(config)
dataset = experiment.test_dataset

def show_cam_on_image(img, mask):
    heatmap = cv2.applyColorMap(np.uint8(255 * mask), cv2.COLORMAP_JET)
    heatmap = np.float32(heatmap) / 255
    cam = heatmap*0.25 + 0.75*np.float32(img)
    cam = cam / np.max(cam)
    return cam

# %%
# %autoreload 2
grad_cam = GradCam(model=network, feature_module=network.mid4.rdbi.layers,
                       target_layer_names=["1"], use_cuda=True)

# %%
preds = []
gts = []
index = np.arange(1000)
np.random.shuffle(index)    
output = 'OpticNet-Explained-GradCam_Kermany/'

if not os.path.exists(output):
    os.makedirs(output)
    
for i in index[:2]:
    filename = dataset.filename(i)
    img, gt = dataset[i]
    img = img.unsqueeze(0).cuda()
    
    pred = network(img)
    prob = torch.softmax(pred, dim=1)
    pred = torch.argmax(prob, dim=1)
    argsort = torch.argsort(prob, dim=1, descending=True)
    
    preds.append(pred)
    gts.append(gt)  
    print(img.shape)
    grayscale_cam = grad_cam(img, gt)
    grayscale_cam = cv2.resize(grayscale_cam, (img.shape[2], img.shape[1]))
    
    img = img.squeeze(0).cpu().numpy().transpose((1,2,0))
    fig, axs = plt.subplots(1,2)
    fig.set_size_inches(17,9)
    axs[0].imshow(img)
    axs[0].set_title('Groundtruth: '+ labels[int(gt)] )
    title = ''
    for arg in argsort.squeeze(0)[:2]:
        title = title + ' ' + labels[int(arg)]+', Pr: {:.2%}'.format((prob[0][arg]))

    axs[1].set_title('Predicted: '+ title)
    axs[1].imshow(grayscale_cam)
    
    for ax in axs:
        # Hide grid lines
        ax.grid(False)
        # Hide axes ticks
        ax.set_xticks([])
        ax.set_yticks([])
    plt.tight_layout()
#     filepath = os.path.join(output, filename)
#     plt.savefig(filepath)
    plt.show()
# Out:
# /home/clement/anaconda3/envs/py37/lib/python3.7/site-packages/torch/nn/functional.py:3063: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# torch.Size([1, 3, 384, 384])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-441bd3906d36> in <module>
#      21     gts.append(gt)
#      22     print(img.shape)
# ---> 23     grayscale_cam = grad_cam(img, gt)
#      24     grayscale_cam = cv2.resize(grayscale_cam, (img.shape[2], img.shape[1]))
#      25
#
# ~/Documents/Clement/OCTransformer/pytorch-grad-cam/gradcam.py in __call__(self, input_img, target_category)
#     107         one_hot.backward(retain_graph=True)
#     108
# --> 109         grads_val = self.extractor.get_gradients()[-1].cpu().data.numpy()
#     110
#     111         target = features[-1]
#
# IndexError: list index out of range
