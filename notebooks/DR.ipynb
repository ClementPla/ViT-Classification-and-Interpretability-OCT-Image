# %%
import pandas as pd
import numpy as np

# %%
filepath = '/home/clement/Documents/database/eyePACS/trainLabels.csv'

np.asarray(pd.read_csv(filepath)['image'])
# Out:
# array(['10_left', '10_right', '13_left', ..., '44348_right', '44349_left',
#        '44349_right'], dtype=object)

# %%
pd.read_csv(filepath)
# Out:
#              image  level
# 0          10_left      0
# 1         10_right      0
# 2          13_left      0
# 3         13_right      0
# 4          15_left      1
# 5         15_right      2
# 6          16_left      4
# 7         16_right      4
# 8          17_left      0
# 9         17_right      1
# 10         19_left      0
# 11        19_right      0
# 12         20_left      0
# 13        20_right      0
# 14         21_left      0
# 15        21_right      0
# 16         22_left      0
# 17        22_right      0
# 18         23_left      0
# 19        23_right      0
# 20         25_left      0
# 21        25_right      0
# 22         30_left      1
# 23        30_right      2
# 24         31_left      0
# 25        31_right      0
# 26         33_left      0
# 27        33_right      0
# 28         36_left      1
# 29        36_right      0
# ...            ...    ...
# 35096   44317_left      0
# 35097  44317_right      0
# 35098   44323_left      1
# ...

# %%
filepath = '/home/clement/Documents/database/aptos/train.csv'
df = pd.read_csv(filepath)
df
# Out:
#            id_code  diagnosis
# 0     000c1434d8d7          2
# 1     001639a390f0          4
# 2     0024cdab0c1e          1
# 3     002c21358ce6          0
# 4     005b95c28852          0
# 5     0083ee8054ee          4
# 6     0097f532ac9f          0
# 7     00a8624548a9          2
# 8     00b74780d31d          2
# 9     00cb6555d108          1
# 10    00cc2b75cddd          0
# 11    00e4ddff966a          2
# 12    00f6c1be5a33          0
# 13    0104b032c141          3
# 14    0124dffecf29          1
# 15    0125fbd2e791          0
# 16    012a242ac6ff          2
# 17    014508ccb9cb          0
# 18    0151781fe50b          0
# 19    0161338f53cc          2
# 20    0180bfa26c0b          2
# 21    0182152c50de          0
# 22    01b3aed3ed4c          1
# 23    01c7808d901d          2
# 24    01d9477b1171          0
# 25    01eb826f6467          2
# 26    01f7bb8be950          0
# 27    0212dd31f623          0
# 28    022f820027b8          0
# 29    0231642cf1c2          0
# ...

# %%
import sys
sys.path.append('../')
from nntools.utils import Config


from fundus_experiment import FundusClassification

# %%
config_path = '../config_fundus.yaml'
config = Config(config_path)
exp = FundusClassification(config)

# %%
import random
exp.train_dataset.plot(random.randint(0,1000))

# %%
import random
random.randint(0,10000)
# Out:
# 285

# %%
filename = exp.test_dataset.filename(0).split('.')[0]
exp.test_dataset.plot(random.randint(0, 1000))

# %%
df[df.id_code==filename]
# Out:
#         id_code  diagnosis
# 0  000c1434d8d7          2

# %%
img_names = [os.path.basename(p) for p in exp.test_dataset.img_filepath]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-16d724bf2660> in <module>
# ----> 1 img_names = [os.path.basename(p) for p in exp.test_dataset.img_filepath]
#
# <ipython-input-11-16d724bf2660> in <listcomp>(.0)
# ----> 1 img_names = [os.path.basename(p) for p in exp.test_dataset.img_filepath]
#
# NameError: name 'os' is not defined

# %%
img_names

# %%
import pandas
csv = pandas.read_csv(exp.test_dataset.csv_filepath)
csv_names = np.asarray(csv[exp.test_dataset.file_column])

# %%
csv_names
